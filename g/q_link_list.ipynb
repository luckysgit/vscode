# %% [markdown]
# Great — let's move to **Linked List Easy Questions**.
# These are fundamental for interviews at Google, Amazon, Meta, etc.
#
# ---
#
# # 🔗 **Linked List Question 1 (Easy)**
#
# ### **Problem: Find the length of a linked list**
#
# Given the head of a linked list, return the **number of nodes** in the list.
#
# ### Example:
#
# List:
#
# ```
# 1 → 2 → 3 → 4 → None
# ```
#
# Output:
#
# ```
# 4
# ```
#
# ---
#
# # ⭐ Your Task:
#
# 1. Explain your approach
# 2. Write Python code (using a simple Node class)
#
# Here is a starter template:
#
# ```python
# class Node:
#     def __init__(self, val):
#         self.val = val
#         self.next = None
#
# def length(head):
#     # Your code here
# ```
#
# ---
#
# 👉 Your turn!
# Explain how you will count nodes and then write the code.

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None

def length(head):
    count = 0
    current = head
    
    while current is not None:
        count += 1
        current = current.next
    
    return count

# %%
# Create nodes
a = Node(10)
b = Node(20)
c = Node(30)

# Link nodes
a.next = b
b.next = c

print(length(a))   # Output: 3
# Out:
# 3

# %% [markdown]
# Here is your next **easy Linked List** interview question — perfect for practice!
#
# ---
#
# # 🔗 **Linked List Question (Easy)**
#
# ### **Problem: Find the Middle Node of a Linked List**
#
# Given the head of a singly linked list, return the **middle node**.
#
# If there are two middle nodes (even length), return the **second middle**.
#
# ### **Example**
#
# List:
#
# ```
# 1 → 2 → 3 → 4 → 5
# ```
#
# Output:
#
# ```
# 3
# ```
#
# Even length:
#
# ```
# 1 → 2 → 3 → 4
# ```
#
# Output:
#
# ```
# 3   (second middle)
# ```
#
# ---
#
# # ⭐ Your Task
#
# 1. Explain how to find the middle node
# 2. Write Python code for the function
#
# **Hint:** Use the **slow and fast pointer method**
#
# * slow moves 1 step
# * fast moves 2 steps
# * when fast reaches the end → slow is at the middle
#
# ---
#
# Whenever you're ready, send your **approach + code**!

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None

def middle_node(head):
    # Step 1: Count length
    count = 0
    current = head
    while current:
        count += 1
        current = current.next
    
    # Step 2: find middle index
    mid = count // 2
    
    # Step 3: move to the middle node
    current = head
    for _ in range(mid):
        current = current.next
    
    return current

# %%
def middle_node(head):
    slow = head
    fast = head

    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next

    return slow

# %%
# Create linked list: 1 → 2 → 3 → 4 → 5
head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)
head.next.next.next.next = Node(5)

mid = middle_node(head)
print(mid.val)   # Output: 3
# Out:
# 3
