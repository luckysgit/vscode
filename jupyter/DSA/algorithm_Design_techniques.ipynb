# %% [markdown]
# # Design and Analysis of Algorithms
#
# ```text
# Design and Analysis of Algorithms (DAA) + Data Structures and Algorithms (DSA)
# │
# ├── 1. Fundamentals of Programming
# │
# ├── 2. Complexity Analysis
# │
# ├── 3. Algorithm Design Techniques
# │
# ├── 4. Recursion
# │
# ├── 5. Searching Algorithms
# │
# ├── 6. Sorting Algorithms
# │
# ├── 7. Data Structures
# │
# ├── 8. Trees
# │
# ├── 9. Tree Traversal Techniques
# │
# ├── 10. Graphs
# │
# ├── 11. Graph Traversal Algorithms
# │
# ├── 12. Minimum Spanning Tree Algorithms
# │
# ├── 13. Shortest Path Algorithms
# │
# ├── 14. Hashing
# │
# ├── 15. Advanced DSA Topics
# │
# ├── 16. Mathematical Algorithms
# │
# ├── 17. Computational Paradigms
# │
# └── 18. Complexity Classes
#
#
# ├── 3. Algorithm Design Techniques [➤]
# │   ├── Brute Force
# │   ├── Divide and Conquer
# │   │   ├── Binary Search
# │   │   ├── Merge Sort
# │   │   └── Quick Sort
# │   │
# │   ├── Greedy Algorithms
# │   │   ├── Prim's Algorithm
# │   │   ├── Kruskal's Algorithm
# │   │   ├── Dijkstra Algorithm
# │   │   ├── Huffman Coding
# │   │   └── Fractional Knapsack
# │   │
# │   ├── Dynamic Programming
# │   │   ├── Fibonacci
# │   │   ├── 0/1 Knapsack
# │   │   ├── Matrix Chain Multiplication
# │   │   ├── Longest Common Subsequence
# │   │   ├── Longest Increasing Subsequence
# │   │   └── Coin Change Problem
# │   │
# │   ├── Backtracking
# │   │   ├── N Queens Problem
# │   │   ├── Sudoku Solver
# │   │   ├── Rat in a Maze
# │   │   ├── Hamiltonian Cycle
# │   │   └── Graph Coloring
# │   │
# │   ├── Branch and Bound
# │   │   ├── Travelling Salesman Problem
# │   │   └── 0/1 Knapsack
# │   │
# │   ├── Randomized Algorithms
# │   └── Heuristic Algorithms
# │
#
#
# 3.

# %% [markdown]
# # Algorithm Design Techniques
#
# ```text
# Algorithm Design Techniques
# │
# ├── Brute Force
# │   │
# │   ├── Definition
# │   │   └── Tries all possible solutions
# │   │
# │   ├── Characteristics
# │   │   ├── Simple Implementation
# │   │   ├── No Optimization
# │   │   └── Exhaustive Search
# │   │
# │   ├── Advantages
# │   │   ├── Easy to Understand
# │   │   ├── Easy to Implement
# │   │   └── Guaranteed Solution
# │   │
# │   ├── Disadvantages
# │   │   ├── Slow for Large Inputs
# │   │   ├── High Time Complexity
# │   │   └── Inefficient
# │   │
# │   ├── Time Complexity
# │   │   ├── Best Case
# │   │   ├── Average Case
# │   │   └── Worst Case → Usually Exponential
# │   │
# │   └── Applications
# │       ├── Linear Search
# │       ├── Bubble Sort
# │       ├── Password Cracking
# │       └── Naive String Matching
# │
# ├── Divide and Conquer
# │   │
# │   ├── Definition
# │   │   └── Divides problem into smaller subproblems
# │   │
# │   ├── Steps
# │   │   ├── Divide
# │   │   ├── Conquer
# │   │   └── Combine
# │   │
# │   ├── Properties
# │   │   ├── Recursive Technique
# │   │   ├── Efficient for Large Problems
# │   │   └── Reduces Complexity
# │   │
# │   ├── Algorithms
# │   │   ├── Binary Search
# │   │   ├── Merge Sort
# │   │   └── Quick Sort
# │   │
# │   ├── Advantages
# │   │   ├── Faster Execution
# │   │   ├── Parallel Processing
# │   │   └── Efficient Memory Usage
# │   │
# │   ├── Disadvantages
# │   │   ├── Recursive Overhead
# │   │   └── Complex Implementation
# │   │
# │   ├── Time Complexity
# │   │   ├── Binary Search → O(log n)
# │   │   ├── Merge Sort → O(n log n)
# │   │   └── Quick Sort → O(n log n)
# │   │
# │   └── Applications
# │       ├── Searching
# │       ├── Sorting
# │       ├── Parallel Algorithms
# │       └── Numerical Problems
# │
# ├── Greedy Algorithms
# │   │
# │   ├── Definition
# │   │   └── Makes locally optimal choices
# │   │
# │   ├── Properties
# │   │   ├── Greedy Choice Property
# │   │   ├── Optimal Substructure
# │   │   └── Fast Decision Making
# │   │
# │   ├── Algorithms
# │   │   ├── Prim's Algorithm
# │   │   ├── Kruskal's Algorithm
# │   │   ├── Dijkstra Algorithm
# │   │   ├── Huffman Coding
# │   │   └── Fractional Knapsack
# │   │
# │   ├── Advantages
# │   │   ├── Faster than DP
# │   │   ├── Easy Implementation
# │   │   └── Memory Efficient
# │   │
# │   ├── Disadvantages
# │   │   ├── May Not Give Optimal Solution
# │   │   └── Problem Specific
# │   │
# │   ├── Time Complexity
# │   │   ├── Prim's Algorithm → O(E log V)
# │   │   ├── Kruskal's Algorithm → O(E log E)
# │   │   ├── Dijkstra → O(E log V)
# │   │   └── Huffman Coding → O(n log n)
# │   │
# │   └── Applications
# │       ├── Network Design
# │       ├── Compression
# │       ├── Routing Systems
# │       └── Scheduling Problems
# │
# ├── Dynamic Programming
# │   │
# │   ├── Definition
# │   │   └── Solves overlapping subproblems efficiently
# │   │
# │   ├── Properties
# │   │   ├── Optimal Substructure
# │   │   ├── Overlapping Subproblems
# │   │   └── Memoization
# │   │
# │   ├── Techniques
# │   │   ├── Top Down Approach
# │   │   └── Bottom Up Approach
# │   │
# │   ├── Algorithms
# │   │   ├── Fibonacci
# │   │   ├── 0/1 Knapsack
# │   │   ├── Matrix Chain Multiplication
# │   │   ├── Longest Common Subsequence
# │   │   ├── Longest Increasing Subsequence
# │   │   └── Coin Change Problem
# │   │
# │   ├── Advantages
# │   │   ├── Reduces Repeated Calculations
# │   │   ├── Faster Execution
# │   │   └── Optimal Solutions
# │   │
# │   ├── Disadvantages
# │   │   ├── High Memory Usage
# │   │   └── Complex State Design
# │   │
# │   ├── Time Complexity
# │   │   ├── Fibonacci → O(n)
# │   │   ├── Knapsack → O(nW)
# │   │   └── LCS → O(n²)
# │   │
# │   └── Applications
# │       ├── Optimization Problems
# │       ├── Bioinformatics
# │       ├── Resource Allocation
# │       └── AI Problems
# │
# ├── Backtracking
# │   │
# │   ├── Definition
# │   │   └── Tries all possibilities and backtracks on failure
# │   │
# │   ├── Properties
# │   │   ├── Recursive Approach
# │   │   ├── State Space Tree
# │   │   └── Depth First Search
# │   │
# │   ├── Problems
# │   │   ├── N Queens Problem
# │   │   ├── Sudoku Solver
# │   │   ├── Rat in a Maze
# │   │   ├── Hamiltonian Cycle
# │   │   └── Graph Coloring
# │   │
# │   ├── Advantages
# │   │   ├── Finds All Solutions
# │   │   ├── Good for Constraint Problems
# │   │   └── Systematic Search
# │   │
# │   ├── Disadvantages
# │   │   ├── Slow
# │   │   ├── Exponential Complexity
# │   │   └── High Recursion Depth
# │   │
# │   ├── Time Complexity
# │   │   └── Usually Exponential
# │   │
# │   └── Applications
# │       ├── Puzzle Solving
# │       ├── Game Solving
# │       ├── Path Finding
# │       └── Scheduling
# │
# ├── Branch and Bound
# │   │
# │   ├── Definition
# │   │   └── Optimization technique using bounds
# │   │
# │   ├── Properties
# │   │   ├── State Space Tree
# │   │   ├── Bounding Function
# │   │   └── Optimal Solution Search
# │   │
# │   ├── Problems
# │   │   ├── Travelling Salesman Problem
# │   │   └── 0/1 Knapsack
# │   │
# │   ├── Advantages
# │   │   ├── Better than Brute Force
# │   │   ├── Prunes Search Space
# │   │   └── Finds Optimal Solution
# │   │
# │   ├── Disadvantages
# │   │   ├── Complex Implementation
# │   │   └── High Memory Usage
# │   │
# │   ├── Time Complexity
# │   │   └── Worst Case Exponential
# │   │
# │   └── Applications
# │       ├── Optimization Problems
# │       ├── Scheduling
# │       └── Route Planning
# │
# ├── Randomized Algorithms
# │   │
# │   ├── Definition
# │   │   └── Uses randomness during execution
# │   │
# │   ├── Types
# │   │   ├── Las Vegas Algorithms
# │   │   └── Monte Carlo Algorithms
# │   │
# │   ├── Advantages
# │   │   ├── Simpler Solutions
# │   │   ├── Faster Average Performance
# │   │   └── Useful in Large Problems
# │   │
# │   ├── Disadvantages
# │   │   ├── Non Deterministic
# │   │   └── May Produce Different Outputs
# │   │
# │   ├── Applications
# │   │   ├── Cryptography
# │   │   ├── Randomized Quick Sort
# │   │   └── Machine Learning
# │   │
# │   └── Time Complexity
# │       └── Depends on Probability
# │
# └── Heuristic Algorithms
#     │
#     ├── Definition
#     │   └── Uses practical methods for near optimal solutions
#     │
#     ├── Properties
#     │   ├── Approximation Based
#     │   ├── Faster Execution
#     │   └── Problem Specific
#     │
#     ├── Advantages
#     │   ├── Fast for Complex Problems
#     │   ├── Good Practical Results
#     │   └── Handles NP Hard Problems
#     │
#     ├── Disadvantages
#     │   ├── No Guaranteed Optimal Solution
#     │   └── Accuracy Depends on Heuristic
#     │
#     ├── Applications
#     │   ├── Artificial Intelligence
#     │   ├── Robotics
#     │   ├── Route Optimization
#     │   └── Scheduling
#     │
#     └── Examples
#         ├── Genetic Algorithms
#         ├── Simulated Annealing
#         ├── Ant Colony Optimization
#         └── Hill Climbing

# %% [markdown]
# #brut force

# %%
#divide and conqure

class DivideConquer:
    def __init__(self):
        self.x = [1, 2, 4, 5, 7, 9]

    def binary_search(self, c):
        low = 0
        high = len(self.x) - 1

        while low <= high:
            mid = (low + high) // 2

            if self.x[mid] == c:
                return f"{c} found at index {mid}"

            elif self.x[mid] < c:
                low = mid + 1

            else:
                high = mid - 1

        return "Not found"

    def merg_sort(self):
        try:
            x = [12,4,2,2]
            n = len(x)
            mid = n/2

            



dv = DivideConquer()
print(dv.binary_search(7))
# Out:
# 7 found at index 4
